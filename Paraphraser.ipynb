# %% [markdown]
# <a href="https://colab.research.google.com/github/hariomvyas/MLProjects/blob/main/Paraphraser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install git+https://github.com/PrithivirajDamodaran/Parrot.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Parrot.git to /tmp/pip-req-build-pf7xqwe9
#   Running command git clone --filter=blob:none --quiet https://github.com/PrithivirajDamodaran/Parrot.git /tmp/pip-req-build-pf7xqwe9
#   Resolved https://github.com/PrithivirajDamodaran/Parrot.git to commit 720a87a1ee557d8ed8d9a021adbdd1dd5616c5f9
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 21.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.5 MB/s eta 0:00:00
# ...

# %%
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %%
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)

# %%
phrase = "I feel good. I would like to taste some wine. Can you bring me some wine? Don't whine. You will get some wine."
phrases = phrase.split(".")
phrases2 = phrase.split("?")

# %%
phrases2
# Out:
# ['I feel good. I would like to taste some wine. Can you bring me some wine',
#  " Don't whine. You will get some wine."]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  I feel good
# ----------------------------------------------------------------------------------------------------
# ("i'm feeling well", 20)
# ('i feel good', 12)
# ----------------------------------------------------------------------------------------------------
# Input_phrase:   I would like to taste some wine
# ----------------------------------------------------------------------------------------------------
# ("i'd like to taste a bit of wine", 26)
# ("i'd like to taste wine", 23)
# ('i would like to taste a little wine', 20)
# ("i'd like to taste some wine", 18)
# ('i would like to taste wine', 18)
# ('i would like to taste some wine', 13)
# ----------------------------------------------------------------------------------------------------
# Input_phrase:   Can you bring me some wine? Don't whine
# ...
